# %% [markdown]
# Numpy Part 2 Begins As Promised

# %%
# in this part we will make a simple project 
# of using numpy to generate random numbers

# %%
import numpy as np
from random import *

# %%
np.linspace(0,10,100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
sample1 = np.random.normal(size=(4,4))
sample1
# Out:
# array([[-0.30373531,  0.16318558, -0.47358429,  0.87371091],
#        [-1.40632035, -0.78426061, -0.33106708, -1.65413602],
#        [-0.62188069,  0.69207401,  0.46837992, -1.0820268 ],
#        [-0.07419213, -1.40796669, -1.05104948, -1.12486653]])

# %%
rng = np.random.default_rng()

# %%
rng.random()
# Out:
# 0.34756148179666846

# %%
rng.random(10)
# Out:
# array([0.24973496, 0.85059821, 0.14260455, 0.37984954, 0.32013986,
#        0.17407198, 0.84490438, 0.87362393, 0.62377702, 0.98695683])

# %%
rng.random((4,4))
# Out:
# array([[0.35199207, 0.71387202, 0.47362135, 0.49243225],
#        [0.52077096, 0.09200886, 0.2982748 , 0.6954167 ],
#        [0.49617898, 0.98321136, 0.62533437, 0.61685129],
#        [0.70995321, 0.30209937, 0.03147249, 0.61141315]])

# %%
rng_seed =np.random.default_rng(12345)
rng_seed.random()
# Out:
# 0.22733602246716966

# %%
rng.integers(low=0,high=10,size=(3,2))
# Out:
# array([[0, 2],
#        [7, 5],
#        [1, 8]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [9.5,6]

# %%
plt.hist(rng.standard_normal(1000))
# Out:
# (array([  5.,   9.,  65., 132., 260., 255., 173.,  77.,  18.,   6.]),
#  array([-3.40413707, -2.73221156, -2.06028606, -1.38836055, -0.71643504,
#         -0.04450953,  0.62741598,  1.29934149,  1.971267  ,  2.64319251,
#          3.31511802]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(rng.normal(10.5, 6.7, 10000))
# Out:
# (array([  21.,  181.,  788., 1993., 2886., 2421., 1252.,  373.,   77.,
#            8.]),
#  array([-12.88945907,  -7.92952516,  -2.96959124,   1.99034267,
#           6.95027659,  11.9102105 ,  16.87014442,  21.83007833,
#          26.79001225,  31.74994616,  36.70988008]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(rng.exponential(100,10000))
# Out:
# (array([5.94e+03, 2.39e+03, 9.84e+02, 4.13e+02, 1.62e+02, 6.50e+01,
#         2.60e+01, 1.10e+01, 8.00e+00, 1.00e+00]),
#  array([1.04044076e-02, 9.00313610e+01, 1.80052318e+02, 2.70073274e+02,
#         3.60094231e+02, 4.50115188e+02, 5.40136144e+02, 6.30157101e+02,
#         7.20178057e+02, 8.10199014e+02, 9.00219971e+02]),
#  <BarContainer object of 10 artists>)
