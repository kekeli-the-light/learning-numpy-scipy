# %% [markdown]
# Numpy Part 2 Begins As Promised

# %%
# in this part we will make a simple project 
# of using numpy to generate random numbers

# %%
import numpy as np
from random import *

# %%
np.linspace(0,10,100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
sample1 = np.random.normal(size=(4,4))
sample1
# Out:
# array([[ 0.17305348,  0.0321045 ,  1.09423668,  1.16838969],
#        [ 0.63425641,  1.25777419, -0.27894593,  0.94070772],
#        [-0.01636142,  1.4402348 , -1.77723349, -0.02363047],
#        [-0.99058424, -0.12630516, -0.28404615,  1.36703034]])

# %%
rng = np.random.default_rng()

# %%
rng.random()
# Out:
# 0.15316479344001477

# %%
rng.random(10)
# Out:
# array([0.07537364, 0.73433737, 0.20104402, 0.30943038, 0.58126472,
#        0.0378556 , 0.16700937, 0.59494104, 0.97582116, 0.55546764])

# %%
rng.random((4,4))
# Out:
# array([[0.78337667, 0.41841226, 0.09140043, 0.1965328 ],
#        [0.98781968, 0.16765647, 0.9531455 , 0.49829063],
#        [0.98269935, 0.82962632, 0.81972459, 0.95065418],
#        [0.60850868, 0.59200868, 0.58375573, 0.94986687]])

# %%
rng_seed =np.random.default_rng(12345)
rng_seed.random()
# Out:
# 0.22733602246716966

# %%
rng.integers(low=0,high=10,size=(3,2))
# Out:
# array([[0, 2],
#        [8, 0],
#        [9, 5]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [9.5,6]

# %%
plt.hist(rng.standard_normal(1000))
# Out:
# (array([  1.,   6.,  33., 124., 257., 279., 184.,  83.,  26.,   7.]),
#  array([-3.8382633 , -3.10565098, -2.37303866, -1.64042634, -0.90781401,
#         -0.17520169,  0.55741063,  1.29002295,  2.02263527,  2.7552476 ,
#          3.48785992]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(rng.normal(10.5, 6.7, 10000))
# Out:
# (array([   8.,   73.,  474., 1459., 2594., 2807., 1777.,  648.,  145.,
#           15.]),
#  array([-15.58544317, -10.49601885,  -5.40659452,  -0.3171702 ,
#           4.77225412,   9.86167845,  14.95110277,  20.0405271 ,
#          25.12995142,  30.21937574,  35.30880007]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(rng.exponential(100,10000))
# Out:
# (array([5.899e+03, 2.394e+03, 1.010e+03, 3.920e+02, 1.700e+02, 8.400e+01,
#         3.400e+01, 1.000e+01, 5.000e+00, 2.000e+00]),
#  array([6.18877264e-03, 8.80768073e+01, 1.76147426e+02, 2.64218044e+02,
#         3.52288663e+02, 4.40359281e+02, 5.28429900e+02, 6.16500518e+02,
#         7.04571137e+02, 7.92641755e+02, 8.80712374e+02]),
#  <BarContainer object of 10 artists>)
